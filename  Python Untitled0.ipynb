# %%
Write the output of the following
k=[‘a’,’b’,’c’,’d’,’e’]
print(k[-1:-7:-1])

# %%
k=['a','b','c','d','e']

# %%
print(k[-1:-7:-1])
# Out:
# ['e', 'd', 'c', 'b', 'a']

# %%
Reverse a list using Python
list1 = [100, 200, 300, 400, 500]

# %%
list1=[100,200,300,400,500]

# %%
list1.reverse()

# %%
list1
# Out:
# [500, 400, 300, 200, 100]

# %%
Given two numbers, write a python code to find the maximum of these
two numbers.
Sample input: a=2, b=4

# %%
a=2
b=4

# %%
if a>b:
  print(a, "is greatest")
else:
  print(b,"is greatest")
# Out:
# 4 is greatest

# %%
Write a python program to print the current year, month and day

# %%
import datetime
now = datetime.datetime.now()
print ("Current date and time : ")
print (now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Current date and time :
# 2022-12-13 13:17:05

# %%
Write a python function to calculate the factorial of a number (a non
negative integer). The function accepts the number as an argument.
Sample input: 3,
Sample output: 6

# %%
def factorial():
    factorial=1
    num=int(input("Enter a number"))
    if num < 0:
       print("Sorry, factorial does not exist for negative numbers")
    elif num == 0:
       print("The factorial of 0 is 1")
    else:
       for i in range(1,num + 1):
          factorial=factorial*i
       print("The factorial of",num,"is",factorial)

# %%
factorial()
# Out:
# Enter a number5
# The factorial of 5 is 120

# %%
Display all duplicate items from a list given:
10, 20, 60, 30, 20, 40, 30, 60, 70, 80
10.

# %%
a=[10,20,60,30,20,40,30,60,70,80]

# %%
new=[]

# %%
for b in a:
   n=a.count(b)
   if n>1:
     if new.count(b)==0:
       new.append(b)

# %%
new
# Out:
# [20, 60, 30]

# %%
Write a python program to print the numbers from a given number n
till 0 using recursion

# %%
def countdown(n):
    print(n)
    if n==0:
      return 0
    return countdown(n - 1)

# %%
countdown(5)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0
# 0

# %%
Modify the element of a nested list inside the following list:
Sample input : list1 = [5, [10, 15, [20, 25, [30, 35], 40], 45], 50]
Change the element 35 to 3500
     
In [ ]:

# %%
list1 = [5, [10, 15, [20, 25, [30, 35], 40], 45], 50]
list1[1][2][2][1]=3500
print(list1)
# Out:
# [5, [10, 15, [20, 25, [30, 3500], 40], 45], 50]

# %%
Write a while loop to display only alphabets from a string.
Hint: In this question, print only the letters from a string by
skipping all digits and special symbols.

# %%
string=input("Enter String: ")
l=len(string)
c=0
while c<len(string):
     if string[c].isalpha():
       print(string[c])
       c+=1
# Out:
# S
# r
# e
# e
